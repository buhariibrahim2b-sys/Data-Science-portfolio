# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df[["MonthlyCharges"]].mean()
# Out:
# MonthlyCharges    64.761692
# dtype: float64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize =True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df["Contract"].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
pd.crosstab(df["Contract"], df["Churn"])
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
pd.crosstab(df["Contract"], df["Churn"], normalize = "index")
# Out:
# Churn                 No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data=df)
plt.title("Monthly Charges vs Churn")
plt.show()

# %%
# Convert TotalCharge from string to numeric

df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
# Remove rows with NaN

df2= df.dropna()

# %%
df2 = df2.drop("customerID", axis = 1)

# %%
# select features and targets

x = df2.drop("Churn", axis = 1)
y = df2["Churn"]

# %%
# Converting churn labels to binary format.

y_test_binary = y_test.map({"No": 0, "Yes": 1})

# %%
# Encode categorical variable

x_encoded = pd.get_dummies( x, drop_first = True )

# %%
# Importing the necessary tools 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# Train-Test Split

x_train, x_test, y_train, y_test = train_test_split( 
    x_encoded, y, test_size = 0.2, random_state = 42
)

# %%
# Rescaling for standardization
# The model initially failed to converge due to unscaled features with different magnitudes. 
# Applying standardization significantly improved convergence and stability, allowing logistic regression to train efficiently.

from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
# Model Training (Logistic Regression)

model = LogisticRegression(max_iter = 1000)

model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.n_iter_
# Out:
# array([33], dtype=int32)

# %%
y_pred = model.predict(x_test_scaled)
y_pred
# Out:
# array(['No', 'No', 'Yes', ..., 'No', 'No', 'No'],
#       shape=(1407,), dtype=object)

# %%
#Accuracy check

accuracy = accuracy_score(y_pred, y_test)
accuracy
# Out:
# 0.7882018479033405

# %%
# Confusion matrix to check how often is the model correct

cm = confusion_matrix( y_pred, y_test)
cm
# Out:
# array([[917, 182],
#        [116, 192]])

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.89      0.83      0.86      1099
#          Yes       0.51      0.62      0.56       308
#
#     accuracy                           0.79      1407
#    macro avg       0.70      0.73      0.71      1407
# weighted avg       0.81      0.79      0.80      1407

# %%
# Feature_importance
# Feature Importance Analysis: examined logistic regression coefficients to identify churn drivers.

feature_importance = pd.Series(
    model.coef_[0],
    index=x_encoded.columns
).sort_values()

feature_importance.head(20)
# Out:
# tenure                                  -1.445747
# MonthlyCharges                          -0.632801
# Contract_Two year                       -0.567396
# Contract_One year                       -0.314562
# OnlineSecurity_Yes                      -0.155520
# TechSupport_Yes                         -0.143482
# Dependents_Yes                          -0.099848
# OnlineBackup_No internet service        -0.074068
# DeviceProtection_No internet service    -0.074068
# TechSupport_No internet service         -0.074068
# StreamingTV_No internet service         -0.074068
# StreamingMovies_No internet service     -0.074068
# InternetService_No                      -0.074068
# OnlineSecurity_No internet service      -0.074068
# PaymentMethod_Credit card (automatic)   -0.057811
# PhoneService_Yes                        -0.029736
# PaymentMethod_Mailed check              -0.027590
# gender_Male                             -0.015756
# OnlineBackup_Yes                        -0.009050
# ...

# %%
feature_importance.tail(20)
# Out:
# StreamingTV_No internet service         -0.074068
# StreamingMovies_No internet service     -0.074068
# InternetService_No                      -0.074068
# OnlineSecurity_No internet service      -0.074068
# PaymentMethod_Credit card (automatic)   -0.057811
# PhoneService_Yes                        -0.029736
# PaymentMethod_Mailed check              -0.027590
# gender_Male                             -0.015756
# OnlineBackup_Yes                        -0.009050
# Partner_Yes                              0.025058
# MultipleLines_No phone service           0.029736
# DeviceProtection_Yes                     0.040129
# SeniorCitizen                            0.094976
# PaymentMethod_Electronic check           0.123558
# PaperlessBilling_Yes                     0.134580
# MultipleLines_Yes                        0.160546
# StreamingTV_Yes                          0.212963
# StreamingMovies_Yes                      0.222440
# InternetService_Fiber optic              0.650749
# ...

# %%
# Get Predicted Probabilities. This gives probability of Churn = Yes

y_probs = model.predict_proba(x_test_scaled)[:, 1]

# %%
# Threshold Tuning
# Instead of using the default 0.5 threshold, decision thresholds were adjusted to study the precision-recall trade-off.

threshold = 0.6
y_pred_custom = (y_probs >= threshold).astype(int)

# %%
# Classification report

print(classification_report(y_test_binary, y_pred_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87      1033
#            1       0.71      0.35      0.47       374
#
#     accuracy                           0.79      1407
#    macro avg       0.75      0.65      0.67      1407
# weighted avg       0.78      0.79      0.76      1407

# %%
# ROC Curve & AUC Analysis

Model discrimination ability was evaluated

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test_binary, y_probs)
auc_score = roc_auc_score(y_test_binary, y_probs)

plt.plot(fpr, tpr, label=f"AUC = {auc_score:.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve – Churn Model")
plt.legend()
plt.show()
